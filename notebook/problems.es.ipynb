# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import random

def lanzar_dos_dado():
  return random.randint(1, 6) + random.randint(1, 6)

def es_par_mayor_7(var: int):
  return var % 2 == 0 or var > 7

n_sim = 1000 # Número de simulaciones

print(sum(1 for _ in range(n_sim) if es_par_mayor_7(lanzar_dos_dado())) / n_sim)
# Out:
# 0.669

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
def sacar_cinco_bolas():
    return [random.randint(0, 59) for _ in range(5)]

def comprobacion_evento(lista_resultado: list, ball_box: list):
  
  cont=[]
  
  for b in lista_resultado:
    if ball_box[b] == 'White':
        cont.append('w')
    elif ball_box[b] == 'Red':
        cont.append('r')
    elif ball_box[b] == 'Green':
        cont.append('g')
    else:
        cont.append('n')

  return all(item == cont[0] for item in cont) or (cont.count('w') == 3 and cont.count("r") == 2)

ball_box = {}
n_sim = 1000

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"


print(sum(1 for _ in range(n_sim) if comprobacion_evento(sacar_cinco_bolas(), ball_box)) / n_sim)

#ballbox es un diccionario, hacer random de 0 a 59 por 5 veces, hacer metodo comprobar para cumplir condiciones
#el random devuelve una lista de 5 que la lee comprobacion y devuelve true si todas son del mismo color o 3 blancas y 2 rojos
# Out:
# 0.037
